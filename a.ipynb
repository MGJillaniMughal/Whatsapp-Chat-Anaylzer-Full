# %%
import re
import pandas as pd

# %%
f=open('WhatsApp Chat.txt','r',encoding='utf-8')

# %%
data=f.read()

# %%
print(data)
# Out:
# 8/5/20, 10:25 AM - Anus Pak Aims Frd: <Media omitted>
# 8/5/20, 10:25 AM - Rashid Ali Pak Aims: 😍
# 8/5/20, 10:25 AM - Anus Pak Aims Frd: <Media omitted>
# 8/5/20, 10:25 AM - Ali Abdula Frd Pak Aims: Kiya
# 8/5/20, 10:25 AM - Anus Pak Aims Frd: <Media omitted>
# 8/5/20, 10:25 AM - Rashid Ali Pak Aims: <Media omitted>
# 8/5/20, 10:25 AM - Ali Abdula Frd Pak Aims: Wtf
# 8/5/20, 10:25 AM - Anus Pak Aims Frd: <Media omitted>
# 8/5/20, 10:26 AM - Rashid Ali Pak Aims: <Media omitted>
# 8/5/20, 10:26 AM - Ali Abdula Frd Pak Aims: <Media omitted>
# 8/5/20, 10:26 AM - Anus Pak Aims Frd: Kaha tha
# 8/5/20, 10:26 AM - Haris Frd Pak Aims: <Media omitted>
# 8/5/20, 10:26 AM - Ali Abdula Frd Pak Aims: <Media omitted>
# 8/5/20, 10:26 AM - Anus Pak Aims Frd: Han main karta hun
# 8/5/20, 10:27 AM - Haris Frd Pak Aims: <Media omitted>
# 8/5/20, 10:28 AM - Ali Abdula Frd Pak Aims: <Media omitted>
# 8/5/20, 10:28 AM - M. Mobeen Frd Pak Aims: uzair ky be 48
# ...

# %%
pattern = '\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\sAM|PM\s-\s'

# %%
messages = re.split(pattern, data)[1:]
messages
# Out:
# [' - Anus Pak Aims Frd: <Media omitted>\n',
#  ' - Rashid Ali Pak Aims: 😍\n',
#  ' - Anus Pak Aims Frd: <Media omitted>\n',
#  ' - Ali Abdula Frd Pak Aims: Kiya\n',
#  ' - Anus Pak Aims Frd: <Media omitted>\n',
#  ' - Rashid Ali Pak Aims: <Media omitted>\n',
#  ' - Ali Abdula Frd Pak Aims: Wtf\n',
#  ' - Anus Pak Aims Frd: <Media omitted>\n',
#  ' - Rashid Ali Pak Aims: <Media omitted>\n',
#  ' - Ali Abdula Frd Pak Aims: <Media omitted>\n',
#  ' - Anus Pak Aims Frd: Kaha tha\n',
#  ' - Haris Frd Pak Aims: <Media omitted>\n',
#  ' - Ali Abdula Frd Pak Aims: <Media omitted>\n',
#  ' - Anus Pak Aims Frd: Han main karta hun\n',
#  ' - Haris Frd Pak Aims: <Media omitted>\n',
#  ' - Ali Abdula Frd Pak Aims: <Media omitted>\n',
#  ' - M. Mobeen Frd Pak Aims: uzair ky be 48\n',
#  ' - Rashid Ali Pak Aims: <Media omitted>\n',
#  ' - Haris Frd Pak Aims: <Media omitted>\n',
#  ' - Rashid Ali Pak Aims: <Media omitted>\n',
#  ' - Ali Abdula Frd Pak Aims: <Media omitted>\n',
# ...
